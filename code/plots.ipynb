# %%
# Imports / global contants

# csv Dateien sind im Verzeichnis ../data zu finden

import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from matplotlib import figure
import math
import numpy as np
import seaborn as sns
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
import gc
import pylab

from pandas.plotting import parallel_coordinates

# %matplotlib inline

timeFormat = "%Y-%m-%dT%H:%M:%S.%fZ"

export = "../export/"
export_img = "../export/img/"
export_interactions = "../export/interaction/"

path = "../data/"

gtv_colormap = {1: 'rgb(54, 161, 185)', 2: 'rgb(0, 44, 61)', 3: 'rgb(233, 71, 74)'}
plot_bgcolor = 'rgba(239, 240, 231,.7)'

# %%
test = pd.read_csv(rf'{export}results_repeat.csv', sep= ";")
test = test.drop([0,1])

important = pd.DataFrame()
important["rate_completed"] = test["rate_completed"].astype('float')
important["MappingMethod"] = test["Unnamed: 3"]


display(test)

mean = important.groupby("MappingMethod")["rate_completed"].mean()
std = important.groupby("MappingMethod")["rate_completed"].std()

display(mean)
display(std)

# plt.errorbar(mean.index, mean, xerr=0.5, yerr=2.0*std, linestyle='')
# plt.show()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4      Result  \
# 2            01          1          1     direct          6   COMPLETED
# 3            01          1          2     direct          9   COMPLETED
# 4            01          1          3     direct          9   COMPLETED
# 5            01          1          4     direct         15   COMPLETED
# 6            01          1          5     direct         12   COMPLETED
# ...         ...        ...        ...        ...        ...         ...
# 1239         24          3         14   widening          9      FAILED
# 1240         24          3         15   widening         12   COMPLETED
# 1241         24          3         16   widening         12   COMPLETED
# 1242         24          3         17   widening         21   COMPLETED
# 1243         24          3         18   widening          6   COMPLETED
#
#          Result.1     Result.2     Result.3     Result.4  ...  Target.4  \
# ...
